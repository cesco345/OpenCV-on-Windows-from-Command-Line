# %% [markdown]
# # Getting the compiler

# %% [markdown]
# You can get a native Visual Studio C++ compiler, without all the other VS IDE tools by visiting the following link:

# %% [markdown]
# https://msdn.microsoft.com/en-us/library/ms235639.aspx?__hstc=268264337.ff2ee769db95babbdde4ab2e948c27dc.1517091241460.1517094561153.1517158370780.3&__hssc=268264337.1.1517158370780&__hsfp=1660726881

# %%
from IPython.display import Image
Image("image1.png")

# %% [markdown]
#        http://go.microsoft.com/fwlink/?LinkId=691126

# %% [markdown]
# # Getting CMake for Windows
# https://cmake.org/download/

# %%
Image("image2.png")

# %% [markdown]
# # Getting OpenCV Sources
# https://opencv.org/

# %%
Image("image3.png")

# %% [markdown]
# # Getting Python
# https://www.python.org/downloads/

# %%
Image("image4.png")

# %% [markdown]
# If you want to have both versions of python, you can but there are a couple of steps that you have to take.  First download 2.7 and install it using the msi installer.  Make the appropriate changes to your environment variables.
# Download python 3.6 and do the same. Go into the python folder and rename the python.exe binary file, rename it from python  python3

# %%
Image("image5.png")

# %% [markdown]
# # Getttng Numpy and Scipy

# %% [markdown]
# Go to the Unofficial Windows Binaries for Python Extension Packages Website run by Christoph Gohlke, at the Laboratory for Fluorescence Dynamics, University of California, Irvine https://www.lfd.uci.edu/~gohlke/pythonlibs/

# %%
Image("image6.png")

# %% [markdown]
# Download the wheels for numpy27, and numpy36 if you are running two versions of python,

# %%
Image("image7.png")

# %% [markdown]
# and the wheels of Scipy27, and Scipy36 for Scipy.

# %%
Image("image8.png")

# %% [markdown]
# Put the cv2.py file found in the python lib in opencv
# C:\opencv\build\python\2.7\x64

# %%
Image("image9.png")

# %% [markdown]
#  in the site-packages directory inside of python

# %%
Image("image10.png")

# %% [markdown]
# # Getting Extra Contrib Modules for OpenCV

# %% [markdown]
# https://github.com/opencv/opencv_contrib/releases

# %%
Image("image11.png")

# %% [markdown]
# Choose the opencv_contrib link, and download the zip file.

# %%
Image("image12.png")

# %% [markdown]
# Place the opencv_contrib in the opencv directory

# %%
Image("image13.png")

# %%
Image("image14.png")

# %%
Image("image15.png")

# %%
Image("image16.png")

# %%
Image("image17.png")
